-- %%
SELECT 
*,
EXPLODE(o.books) as book

   FROM orders_silver AS o
   where o.order_id = '000000004766'
   ;
  
SELECT 
order_id,
customer_id,
book,
book.*
   FROM orders_silver AS o,
        LATERAL EXPLODE(o.books) AS b(book)
   where o.order_id = '000000004766'
   ;

select * from books_sales
where author = 'Tracy Kidder'
order by order_timestamp
;

CREATE TABLE people10m (
  id INT NOT NULL,
  firstName STRING,
  middleName STRING NOT NULL,
  lastName STRING,
  gender STRING,
  birthDate TIMESTAMP,
  ssn STRING,
  salary INT
);

ALTER TABLE people10m ALTER COLUMN lastName SET NOT NULL;

describe detail people10m;

show tblproperties people10m;
